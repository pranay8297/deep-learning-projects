# %% [markdown]
# <a href="https://colab.research.google.com/github/pranay8297/deep-learning-projects/blob/master/EAI6020_PranayBindela_Module2_SpringTerm_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EAI6020_PranayBindela_Module2_SpringTerm_2022
#
# ### Assignment week - 2
# ### date: 8th June 2022

# %%
# First, we'll import pandas, a data processing and CSV file I/O library
import pandas as pd
import numpy as np
import random
# We'll also import seaborn, a Python graphing library
import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", color_codes=True)

# %%
# Allows the printing of multiple sets of output from the code in one cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
ts_1 = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2022', periods=1000))
ts_1
# Out:
# 2022-01-01   -0.054586
# 2022-01-02    0.453746
# 2022-01-03    0.591399
# 2022-01-04    1.270737
# 2022-01-05    0.464370
#                 ...
# 2024-09-22   -0.723327
# 2024-09-23   -0.325819
# 2024-09-24    0.755060
# 2024-09-25    1.872991
# 2024-09-26   -1.419617
# Freq: D, Length: 1000, dtype: float64

# %%
# Create a data set of 1000 random numbers starting at 1/1/2022 
# Use the pandas cumsum method to calculate the cumulative sum
# Examine the data and make sure that you understand what is going on
ts_1 = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2022', periods=1000))
ts_1.head(10)
ts_2 = ts_1.cumsum()
ts_2.head(10)
ts_2.plot()
# Out:
# 2022-01-01    1.100925
# 2022-01-02    1.263160
# 2022-01-03   -0.501210
# 2022-01-04   -0.020808
# 2022-01-05    1.313305
# 2022-01-06    0.163646
# 2022-01-07    0.483084
# 2022-01-08    1.820800
# 2022-01-09   -0.072513
# 2022-01-10   -0.938245
# Freq: D, dtype: float64
# 2022-01-01    1.100925
# 2022-01-02    2.364085
# 2022-01-03    1.862875
# 2022-01-04    1.842067
# 2022-01-05    3.155372
# 2022-01-06    3.319019
# 2022-01-07    3.802103
# 2022-01-08    5.622903
# 2022-01-09    5.550390
# 2022-01-10    4.612144
# Freq: D, dtype: float64

# %%
# Generate 1000 data points as in the previous cell - 
# give it a different object name 
# and plot the series
ts_3 = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2022', periods=1000))
ts_3.plot()

# %%
# Create a data frame with 5 series of 1000 data points
# Uses the ts_1 index created in the previous cells
# Plot the time series using plot. 

data_range = pd.date_range('1/1/2022', periods=1000)

def get_series_with_name(iter, dr = data_range):
  s = pd.Series(np.random.randn(1000), index = dr)
  s.name = f's_{str(iter)}'
  return s.cumsum()

df = pd.concat([get_series_with_name(i+1) for i in range(5)], axis=1)
df.head()
# Out:
#                  s_1       s_2       s_3       s_4       s_5
# 2022-01-01  0.592836 -0.773240 -2.258175  0.048198  0.891005
# 2022-01-02  1.041227 -0.881937 -2.196410  0.025851  0.589714
# 2022-01-03  0.637731 -0.960613 -3.975219 -0.379062  0.043419
# 2022-01-04  0.268094  1.247305 -5.190105  0.197928  1.124273
# 2022-01-05  1.232763  2.326284 -5.471262 -0.470767  1.825458

# %%
# Plot the data points in the above data frame
plt.figure(); 
df.plot(ax=plt.gca())
df.plot.scatter(x="s_1", y="s_2", c="DarkBlue")

# %%
# The purpose of using plt.figure() is to create a figure object.
# The whole figure is regarded as the figure object. 
# It is necessary to explicitly use plt.figure() 
# when we want to tweak the size of the figure and 
# when we want to add multiple Axes objects in a single figure.

# .iloc[] is primarily integer position based - from 0 to length-1 of the 
# axis; Here we use the slice object - to create a 5 by 5 data frame
# Take a slice of 10 data points and create bar plots 
# .iloc[] is primarily integer position based - from 0 to length-1 of the 
# axis; Use the slice object - to create a 10 by 10 data frame
# Plot the bar plot and use plt.axhline(0, color='r') to 
# draw a red hline at 'y' = 0 that spans the xrange:

plt.figure();

subset_5x5 = df.iloc[0:5, 0:]
subset_5x5.plot.bar(rot=0, figsize=(20, 10))

# %%
# 10 by 10 data

slice_10x10 = df.iloc[0:10, 0:]
slice_10x10.plot.bar(figsize=(20, 10));
plt.axhline(0, color='r');
plt.show();

# %%
# Create a data frame with 5 series of 1000 data points using np.random.rand
# Pint out the shape and summary statistics using describe()

index = range(1000)

df_2 = pd.concat([get_series_with_name(i+1, index) for i in range(5)], axis=1)
df_2.describe()
# Out:
#                s_1          s_2          s_3          s_4          s_5
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    -18.362115   -31.571036   -13.292995   -11.571857     7.555332
# std      14.443949    24.693437    11.736270    15.348815     7.118603
# min     -55.520886   -77.621825   -42.301490   -38.588942    -5.582290
# 25%     -21.959432   -44.409749   -21.807767   -26.602953     1.688430
# 50%     -13.531828   -27.866328   -10.495454    -9.037917     7.491844
# 75%      -8.913733   -18.844753    -4.510438     2.512744    13.772287
# max       5.534992    13.584480     7.272975    13.179854    24.681597

# %%
# Produce a multiple bar plot using the DataFrame’s plot.bar() method :
plt.figure()
slice_10x10.plot.bar(rot=0, figsize=(20, 10), subplots=True) 
plt.axhline(0, color='r');
plt.show()
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fc381aef410>,
# ...
#       dtype=object)

# %%
# Produce a stacked bar chart use stacked = True

plt.figure()
slice_10x10.plot.bar(rot=0, figsize=(20, 10), stacked=True) 
plt.axhline(0, color='black');
plt.show()

# %%
range(1, 2000, 2)
# Out:
# range(1, 2000, 2)

# %%
# Create a data frame with three variables of 1000 observations. The first
# should be a set of random numbers with an increment of +2, 
# the second should be purely random numbers and the third a set of 
# random numbers with an increment of -2.
# Display the first 5 observation using head, the shape of the data frame 
# and summary statistics using describe()

index = range(1000)

def get_series_from_index_values(values, name, index = index):
  s = pd.Series(values, index = index)
  s.name = name
  return s
  
df_3 = pd.concat([get_series_from_index_values(range(1, 2000, 2), 's1'), get_series_from_index_values(np.random.randn(1000), 's2'), get_series_from_index_values(range(2000, 1, -2), 's3')], axis=1)
df_3.head()
# Out:
#    s1        s2    s3
# 0   1 -0.479384  2000
# 1   3 -2.403487  1998
# 2   5  1.054598  1996
# 3   7 -0.007098  1994
# 4   9  0.761095  1992

# %%
print(df_3.shape)
# Out:
# (1000, 3)

# %%
df_3.describe()
# Out:
#                 s1           s2           s3
# count  1000.000000  1000.000000  1000.000000
# mean   1000.000000    -0.019176  1001.000000
# std     577.638872     0.984088   577.638872
# min       1.000000    -3.260839     2.000000
# 25%     500.500000    -0.723788   501.500000
# 50%    1000.000000    -0.009057  1001.000000
# 75%    1499.500000     0.657515  1500.500000
# max    1999.000000     3.258848  2000.000000

# %%
# Histograms can be drawn using the DataFrame.plot.hist() and 
# Series.plot.hist() methods. 
# Plot the histogram of the above data frame created in the previous cell

df_3['s2'].plot.hist(figsize=(20, 10))

# %%
# A histogram can be stacked using stacked=True. 
# Draw a stacked histogram of the above dataframe
# Bin size can be changed using the bins keyword.
df_4 = df.iloc[:, :3]
df_4.plot.hist(figsize=(20, 10), stacked = True, bins = 100)

# %%
# np.random.uniform(0, 1, 10)
dict([('a', 1), ('b', 2)])
# Out:
# {'a': 1, 'b': 2}

# %%
# Boxplot can be drawn calling Series.plot.box() and DataFrame.plot.box(),
# or DataFrame.boxplot() to visualize the distribution of 
# values within each column.
# Draw a boxplot representing 10 trials of 10 observations of a 
# uniform random variable on [0,1).

plt.figure()
vals = dict([(f's_{str(i)}', np.random.uniform(0, 1, 10)) for i in range(10)])

df_5 = pd.DataFrame(vals) 
df_5.plot.box(grid='True', figsize=(20, 10))
plt.show()

# %%
# Boxplot can be colorized by passing color keyword. 
# You can pass a dict whose keys are boxes, whiskers, medians and caps. 
# If some keys are missing in the dict, 
# default colors are used for the corresponding artists. 
# Also, boxplot has sym keyword to specify fliers style.

# When you pass other type of arguments via color keyword, 
# it will be directly passed to matplotlib for all the boxes, 
# whiskers, medians and caps colorization.

# The colors are applied to every boxes to be drawn. 
# If you want more complicated colorization, 
# you can get each drawn by passing return_type.
# Colorize the box plots: boxes: green, whiskers: orange, 
# medians: blue and caps as red.
plt.figure()
df_5.plot.box(grid='True',
                             figsize=(20, 10),
color=dict(boxes='blue', whiskers='black', medians='red', caps='green'))
plt.show()

# %%
# Scatter Plots - create a data frame with 100 random numbers and 
# 5 variables. Use head and shape

vals = dict([(f's_{str(i)}', np.random.randn(100)) for i in range(5)])

df_6 = pd.DataFrame(vals) 
print(df_6.shape)
df_6.head()
# Out:
# (100, 5)
#         s_0       s_1       s_2       s_3       s_4
# 0 -0.091119  2.343050 -1.409059 -0.477039 -0.563912
# 1 -1.195241 -2.492791  0.916440  0.457376  1.930966
# 2  0.043383  0.019371  0.451962  0.845840  0.102669
# 3  0.482657 -0.924046  1.116350  1.657498  0.228626
# 4  1.018273  0.359792  0.923622  1.441384  0.422738

# %%
# Create a scatter plot of any two variables from the dataframe in the 
# above cell
plt.figure();
df_6.plot.scatter(x='s_0', y='s_2', c='blue ')

# %%
# Plot multiple column groups in a single axes, 
# Repeat plot method specifying target axis
# Create axes for the first using blue color and label the groups appropriately

plt.figure();
ax = df_6.plot(kind='scatter', x='s_1', y='s_3', c='Blue', label='s1 and s3')
df_6.plot.scatter(x='s_0', y='s_2', c='Red', label='s0 and s4', ax=ax)

# %%
# Create a bubble chart using a scatter plot for two variables and 
# a column of the data frame as an index of size. 
# Your result should show a scatter plot with the third variable as a 
# proxy for size
plt.scatter('s_0', 's_1', s = 's_2', c= 's_3', alpha=1.0, data = df_6) 
plt.xlabel('s_0')
plt.ylabel('s_1')
# Out:
# Text(0.5, 0, 's_0')
# Text(0, 0.5, 's_1')

# %%
# Plotting Tools
# These functions can be imported from pandas.plotting and take a 
# Series or DataFrame as an argument.

# Scatter Matrix Plot
# You can create a scatter plot matrix using the scatter_matrix 
# method in pandas.plotting:
# alpha is the amount of transparency applied
# diagonal - Pick between ‘kde’ and ‘hist’ for either Kernel Density 
# Estimation or Histogram plot in the diagonal.
# In statistics, kernel density estimation (KDE) is a non-parametric way 
# to estimate the probability density function (PDF) of a random variable.
# Vary alpha and observe how transparency works
# Use kde in the first plot and hist in the second
from pandas.plotting import scatter_matrix
vals = dict([(f's_{str(i)}', np.random.randn(1000)) for i in range(5)])

df_7 = pd.DataFrame(vals) 
df_7.shape
# First generate a dataframe of 1000 observatins with 5 variables
# Use pd.plotting to create the plots as shown in class
# Out:
# (1000, 5)

# %%
scatter_matrix(df_7, alpha=0.6, diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc36bcbe510>,
# ...
#       dtype=object)

# %%
scatter_matrix(df_7, alpha=0.6, diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc367d38610>,
# ...
#       dtype=object)
